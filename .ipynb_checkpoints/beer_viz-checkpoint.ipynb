# %%
from get_data import *
# Out:
# 2018-11-12 12:31:34,208 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-11-12 12:31:34,209 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-12 12:31:34,211 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-11-12 12:31:34,212 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-12 12:31:34,214 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("styles")
# 2018-11-12 12:31:34,216 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-12 12:31:34,218 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("beers")
# 2018-11-12 12:31:34,219 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-12 12:31:34,222 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE styles (
# 	id INTEGER NOT NULL,
# 	name TEXT,
# 	"shortName" TEXT,
# 	"nameDisplay" TEXT,
# 	category TEXT,
# 	description TEXT,
# 	"abvMin" FLOAT,
# 	"abvMax" FLOAT,
# 	"ibuMin" FLOAT,
# 	"ibuMax" FLOAT,
# 	PRIMARY KEY (id)
# )
#
#
# ...

# %%
session.query(Beer.name).join(Style, Style.id == Beer.style_id).filter(Style.shortName == "American Imperial Stout").all()
# Out:
# 2018-11-12 14:27:54,795 INFO sqlalchemy.engine.base.Engine SELECT beers.name AS beers_name
# FROM beers JOIN styles ON styles.id = beers.style_id
# WHERE styles."shortName" = ?
# 2018-11-12 14:27:54,797 INFO sqlalchemy.engine.base.Engine ('American Imperial Stout',)
# [("30th Anniversary - Fritz and Ken's Ale"),
#  ('Barrel Aged Imperial Cherry Stout'),
#  ('Barrel Aged Narwhal'),
#  ('Barrel-Aged Ten Fidy'),
#  ('Bourbon Barrel Aged Imperial Stout'),
#  ('Bourbon Barrel Aged Imperial Stout With Coffee'),
#  ('Brandy Barrel-Aged Ten Fidy'),
#  ('Chocolate Chili Stout - High Altitude Series'),
#  ("Dank Tank Old Man Johnson's Farm"),
#  ("Dragon's Milk"),
#  ("Dragon's Milk Reserve Coconut Rum"),
#  ("Dragon's Milk Reserve Mexican Spice Cake"),
#  ("Dragon's Milk Reserve Triple-Mashed"),
#  ("Dragon's Milk Reserve Vanilla Chai"),
#  ("Dragon's Milk Reserve with Coffee And Chocolate"),
#  ("Dragon's Milk Reserve with S'mores"),
#  ("Dragon's Milk Reserve with Toasted Chilies"),
# ...

# %%
session.query(Beer.name, Beer.description).join(Style).filter(Style.shortName == "American Imperial Stout").all()
# Out:
# 2018-11-12 12:48:34,970 INFO sqlalchemy.engine.base.Engine SELECT beers.name AS beers_name, beers.description AS beers_description
# FROM beers JOIN styles ON styles.id = beers.style_id
# WHERE styles."shortName" = ?
# 2018-11-12 12:48:34,971 INFO sqlalchemy.engine.base.Engine ('American Imperial Stout',)
# [("30th Anniversary - Fritz and Ken's Ale", None),
#  ('Barrel Aged Imperial Cherry Stout',
#   'Aged in 50% Whiskey & 50% port wine barrels'),
#  ('Barrel Aged Narwhal',
# ...

# %%
import nltk
import re
from nltk.corpus import stopwords
stopwords = stopwords.words('english') #set stopwords as a global variable

#a list of lists populated with each descriptions as a list of words as string
def get_descriptions(shortname):
    list_of_descriptions = session.query(Beer.description).join(Style).filter(Style.shortName == shortname).filter(Beer.description != None).all()
    return [description[0].split() for description in list_of_descriptions]


#returns a list of sentences as strings
def get_all_words(shortName):
    b = []
    for i in get_descriptions(shortName):
        new_i = ' '.join(i)
        b.append(new_i)
    return b

#splits the sentences into one list of strings
def desc_to_string(shortName):
    new_list = []
    for x in get_all_words(shortName):
        new_list.append(x)
    first_string = ' '.join(new_list)
    words_first_string = re.sub(r'[^\w\s]','',first_string)
    final_string = words_first_string.split()
    return final_string
	

#counts the number of key words
def count_key_words(shortName):
    mynewtext = [w for w in desc_to_string(shortName) if w not in stopwords]
    mynewtext
    fdist1 = nltk.FreqDist(mynewtext)
    return fdist1.most_common(50)


words = [word[0] for word in count_key_words("American Imperial Stout")]
counts = [word[1] for word in count_key_words("American Imperial Stout")]

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
import plotly.graph_objs as go
init_notebook_mode(connected=True)
iplot([{"x": words, "y": counts}])
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...
