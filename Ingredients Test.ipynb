# %%
from get_data_2 import *
# Out:
# 2018-11-14 17:39:12,562 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-11-14 17:39:12,563 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-14 17:39:12,565 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-11-14 17:39:12,566 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-14 17:39:12,569 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("styles")
# 2018-11-14 17:39:12,570 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-14 17:39:12,572 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("beers")
# 2018-11-14 17:39:12,572 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-14 17:39:12,574 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("ingredients")
# 2018-11-14 17:39:12,574 INFO sqlalchemy.engine.base.Engine ()
# 2018-11-14 17:39:12,576 INFO sqlalchemy.engine.base.Engine PRAGMA table_info("beer_ingredients")
# 2018-11-14 17:39:12,576 INFO sqlalchemy.engine.base.Engine ()
# ...

# %%
id_list = GetBeerData()
id_list.get_beer_data()
ids_and_ingredients()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8f8368b0bed9> in <module>()
# ----> 1 id_list = GetBeerData()
#       2 id_list.get_beer_data()
#       3 ids_and_ingredients()
#
# NameError: name 'GetBeerData' is not defined

# %%
for beer in ids_and_ingredients():
    matched_beer = session.query(Beer).filter(Beer.beercode == beer['beercode'])[0]
    for ingredient in beer['data']:
        matched_beer.ingredientcode = ingredient['id']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a0f4a5e4225a> in <module>()
# ----> 1 beer_ingredient_ids()
#
# ~/Documents/Flatiron_DS/Projects/module_one_project/get_data_2.py in beer_ingredient_ids()
#     140 def beer_ingredient_ids():
#     141     for beer in ids_and_ingredients():
# --> 142         matched_beer = session.query(Beer).filter(Beer.beercode == beer['beercode'])[0]
#     143         list_of_ingredients = []
#     144         for ingredient in beer['data']:
#
# NameError: name 'session' is not defined
